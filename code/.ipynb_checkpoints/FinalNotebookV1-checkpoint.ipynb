# %% [markdown]
# # Social Media Analytics Assignment #1
#
# Siraj Hatoum,
# Mohamad Khalili,
# Mehdi Yachfine,
# Hirad Nourbakhsh,
# Brock Beckley

# %% [markdown]
# ## Part 1 - Find Predictors of Influence

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
data_dir = '../data/'

# %% [markdown]
# Importing the Dataset

# %%
df = pd.read_csv(data_dir+'train.csv')
df = df.dropna()
df.head()
# Out:
#    Choice  A_follower_count  A_following_count  A_listed_count  \
# 0       0               228                302               3
# 1       0             21591               1179             228
# 2       0              7310               1215             101
# 3       0                20                  7               2
# 4       1             45589                862            2641
#
#    A_mentions_received  A_retweets_received  A_mentions_sent  A_retweets_sent  \
# 0             0.583979             0.100503         0.100503         0.100503
# 1            90.456506            25.798292         5.709329         1.111159
# 2            25.503644             9.556347         5.361519         0.591206
# 3             7.690824             0.277306         1.331508         0.100503
# 4           148.854279            36.998884        27.881768         3.333492
#
#      A_posts  A_network_feature_1  ...  B_following_count  B_listed_count  \
# 0   0.362150                    2  ...              29808            1689
# 1   5.176620                  369  ...                848            1610
# 2   3.589718                   95  ...                482             206
# 3   2.830627                    6  ...              17637             278
# 4  23.861282                  551  ...               1711             181
#
#    B_mentions_received  B_retweets_received  B_mentions_sent  B_retweets_sent  \
# 0            15.430498             3.984029         8.204331         0.332423
# 1            40.495021             8.943607         3.227677         0.564343
# 2             0.734696             0.354379         0.603202         0.100503
# 3           572.874856           390.293681        27.552040         7.167557
# 4            21.601866             3.581661         6.764657         1.119727
#
#      B_posts  B_network_feature_1  B_network_feature_2  B_network_feature_3
# 0   6.988815                   66            75.530303          1916.893939
# 1   1.070321                  163           132.030675          2931.515337
# 2   0.603202                    3            10.333333           277.333333
# 3  32.101906                 1762            23.469296          1395.845634
# 4   4.563246                   85            48.500000          1993.627907
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Feature Engineering
#
# In this section, we are creating new features based on the features available in the dataset. Since the goal is to identify whether influencer A is more influential than influencer B, instead of having individual metrics for both influencers, we create comparison metrics. For instance, instead of having the individual follower count for each influencer, we have the difference in followers count between influencers A and B. The ratio could have also been calculated, but we chose to go with the difference, to avoid potential divisions by 0.
#
# We tried engineering more advanced features, such as the level of interaction, defined by the sum of retweets and mentions, divided by the total number of followers for a given influencer. However, as will be shown further down, those features did not have a significant importance in predicting influence.

# %%
#follower count difference
df['Follower Count Difference'] = df['A_follower_count'] - df['B_follower_count'] 
#following count difference
df['Followig Count Difference'] = df['A_following_count'] - df['B_following_count'] 
#listed count difference
df['Listed Count Difference'] = df['A_listed_count'] - df['B_listed_count'] 
#received retweets difference
df['Received Retweets Difference'] = df['A_retweets_received'] - df['B_retweets_received'] 
#received mention difference
df['Received Mentions Difference'] = df['A_mentions_received'] - df['B_mentions_received']
#sent retweets difference
df['Sent Retweets Difference'] = df['A_retweets_sent'] - df['B_retweets_sent'] 
#sent mentions difference
df['Sent Mentions Difference'] = df['A_mentions_sent'] - df['B_mentions_sent'] 
#post difference
df['Post Difference'] = df['A_posts'] - df['B_posts']

###################################################################################################################
#Ratio of interactions (retweets received + mentions received)/posts -- NOT VERY USEFUL
#df['Interaction Ratio A'] = (df['A_retweets_received'] + df['A_mentions_received'])/df['A_follower_count']
#df['Interaction Ratio B'] = (df['B_retweets_received'] + df['B_mentions_received'])/df['B_follower_count']

#Listed/follower ratio --- NOT VERY USEFUL
#df['LF Ratio A'] = df['A_listed_count']/df['A_follower_count']
#df['LF Ratio B'] = df['B_listed_count']/df['B_follower_count']

#ratio of infulencer's posts that are retweeted ---- NOT VERY USEFUL
#df['Retweet % A'] = df['A_retweets_received']/df['A_posts']
#df['Retweet % B'] = df['B_retweets_received']/df['B_posts']

#Calculating following/followers ratio for each influencer ------ NOT VERY USEFUL
#df['following/followers_A'] = df['A_following_count']/df['A_follower_count']
#df['following/followers_B'] = df['B_following_count']/df['B_follower_count']

# %%
#Dropping the features that were precursors to the newly designed features:

df = df.drop(columns = ['A_follower_count',
                   'A_following_count',
                   'A_listed_count',
                   'A_mentions_received',
                   'A_retweets_received',
                   'A_mentions_sent',
                   'A_retweets_sent',
                   'A_posts', 
                   'B_follower_count',
                   'B_following_count',
                   'B_listed_count',
                   'B_mentions_received',
                   'B_retweets_received',
                   'B_mentions_sent',
                   'B_retweets_sent',
                   'B_posts'])
df.head()
# Out:
#    Choice  A_network_feature_1  A_network_feature_2  A_network_feature_3  \
# 0       0                    2           166.500000         11355.000000
# 1       0                  369            18.442971          1330.366048
# 2       0                   95            68.927835          5999.896907
# 3       0                    6             2.000000            96.166667
# 4       1                  551           127.404293          2833.847943
#
#    B_network_feature_1  B_network_feature_2  B_network_feature_3  \
# 0                   66            75.530303          1916.893939
# 1                  163           132.030675          2931.515337
# 2                    3            10.333333           277.333333
# 3                 1762            23.469296          1395.845634
# 4                   85            48.500000          1993.627907
#
#    Follower Count Difference  Followig Count Difference  \
# 0                     -34235                     -29506
# 1                     -17671                        331
# 2                       3688                        733
# 3                     -19542                     -17630
# 4                      38035                       -849
#
#    Listed Count Difference  Received Retweets Difference  \
# 0                    -1686                     -3.883525
# 1                    -1382                     16.854685
# 2                     -105                      9.201969
# 3                     -276                   -390.016375
# 4                     2460                     33.417223
#
#    Received Mentions Difference  Sent Retweets Difference  \
# 0                    -14.846518                 -0.231920
# 1                     49.961485                  0.546816
# 2                     24.768949                  0.490702
# 3                   -565.184032                 -7.067053
# 4                    127.252413                  2.213765
#
#    Sent Mentions Difference  Post Difference
# 0                 -8.103828        -6.626665
# 1                  2.481652         4.106299
# 2                  4.758317         2.986516
# 3                -26.220532       -29.271279
# 4                 21.117111        19.298035

# %% [markdown]
# ### Feature Importance
#
# In order to compute the relative important of each feature in our newly engineered dataset, an initial random forest model was run. That way, we have a quantitative way of assessing the importance of each predictor, which will reinforce/confirm domain knowledge when identifying the most important predictors of influence.

# %%
X = df.drop(columns = 'Choice')
y = df['Choice']

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
rf = RandomForestClassifier(random_state = 0, n_estimators = 500)
model = rf.fit(X_std,y)

model.feature_importances_

importances = pd.DataFrame(list(zip(X.columns,model.feature_importances_)), columns = ['predictor','feature importance'])

importances.sort_values(by = 'feature importance', ascending = False)
# Out:
#                        predictor  feature importance
# 8        Listed Count Difference            0.148427
# 6      Follower Count Difference            0.121338
# 10  Received Mentions Difference            0.110956
# 9   Received Retweets Difference            0.099928
# 3            B_network_feature_1            0.070874
# 0            A_network_feature_1            0.069579
# 13               Post Difference            0.055813
# 12      Sent Mentions Difference            0.054854
# 7      Followig Count Difference            0.053043
# 2            A_network_feature_3            0.044415
# 5            B_network_feature_3            0.043161
# 1            A_network_feature_2            0.042945
# 11      Sent Retweets Difference            0.042585
# 4            B_network_feature_2            0.042082

# %% [markdown]
# ### Training and testing the model

# %%
from sklearn.model_selection import train_test_split

X = df[['Listed Count Difference',
        'Follower Count Difference',
        'Received Mentions Difference',
        'Received Retweets Difference',
        'B_network_feature_1',
        'A_network_feature_1',
        'Post Difference']]

y = df['Choice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.05, random_state=5)

X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

model = rf.fit(X_train_std,y_train)
y_pred = model.predict(X_test_std)

print(round(accuracy_score(y_pred,y_test),3)*100,'% accuracy')
# Out:
# 83.3 % accuracy

# %% [markdown]
# ### Financial Analysis

# %%
#Probability of follower purchasing product
non_influencer = 0
influencer_tweet = 0.0002 #percent of followers purchasing with one tweet
influencer_tweet2 = 0.0003 #percent of followers purchasing with two tweets

# %%
#Sales & Cost Info
profitmargin = 10 #One customer can only buy one unit
tweet_cost = 5 #Without analytics for one tweet
tweet_cost_analytics = 10 #With analytics for two tweets
tweet_cost_noninf = 0 #Tweet cost for non-influencer

# %%
wrong_observations = []

for i in range(len(y_pred)):
    if (y_test.iloc[i] != y_pred[i]):
        wrong_observations.append(y_test.index[i])

# %%
correct_observations = []

for i in range(len(y_pred)):
    if (y_test.iloc[i] == y_pred[i]):
        correct_observations.append(y_test.index[i])

# %%
test_observations = correct_observations + wrong_observations

# %%
df1 = pd.read_csv(data_dir+'train.csv')

# %%
df1 = df1[df1.index.isin(test_observations)]
df1.head()
# Out:
#     Choice  A_follower_count  A_following_count  A_listed_count  \
# 33       1            130850               3394             449
# 40       0            627949             150866            6820
# 51       1            232753                320            7919
# 64       1           1352348                331           15647
# 67       0             49326              42259            1446
#
#     A_mentions_received  A_retweets_received  A_mentions_sent  \
# 33            92.869651            16.538484         2.548048
# 40           246.403846            74.705430        21.260939
# 51           175.264776           100.480820         3.108490
# 64         19129.848662         14552.733991         2.065418
# 67             0.452340             0.275538         0.100503
#
#     A_retweets_sent    A_posts  A_network_feature_1  ...  B_following_count  \
# 33         0.100503   3.036688                  355  ...                431
# 40         1.320681  15.278066                  683  ...                  6
# 51         1.614717   4.401919                  679  ...                293
# 64         0.580955  16.281502                52580  ...                673
# 67         0.100503   0.100503                    2  ...               4524
#
#     B_listed_count  B_mentions_received  B_retweets_received  B_mentions_sent  \
# 33              44             0.555204             0.100503         0.100503
# 40            2963            98.954241            27.797596         0.796262
# 51             970          1729.451634           763.659739        30.829977
# 64             747            55.993546            22.321945         6.946233
# 67           11946          6782.405338          2944.524245        12.955723
#
#     B_retweets_sent    B_posts  B_network_feature_1  B_network_feature_2  \
# 33         0.100503   0.595962                    2           836.000000
# 40         0.332423   0.332423                  430           241.680460
# 51         8.568367  93.311571                 4067            12.310269
# 64         0.341936   6.503977                  202           152.495098
# 67         2.791861  66.206208                21678             6.859364
#
#     B_network_feature_3
# 33         11447.500000
# 40          8490.301149
# 51          1636.379704
# 64          3286.617647
# 67          1113.202016
#
# [5 rows x 23 columns]

# %%
#Without Analytics
df1['Expected_Return_No_Analytics'] = ''
df1.loc[df1["Choice"] == 1, 'Expected_Return_No_Analytics'] = (df1["A_follower_count"] * influencer_tweet)*profitmargin - tweet_cost*2
df1.loc[df["Choice"] == 0, 'Expected_Return_No_Analytics'] = (df1["B_follower_count"] * influencer_tweet)*profitmargin - tweet_cost*2
Total_noanalytics = df1["Expected_Return_No_Analytics"].sum()
print("Total Expected Return without analytics is $", round(Total_noanalytics,2))
# Out:
# Total Expected Return without analytics is $ 653549.22

# %%
#Perfect Model
df1['Expected_Return_Perfect'] = ''
df1.loc[df["Choice"] == 1, 'Expected_Return_Perfect'] = (df1["A_follower_count"] * influencer_tweet2)*profitmargin - tweet_cost_analytics
df1.loc[df["Choice"] == 0, 'Expected_Return_Perfect'] = (df1["B_follower_count"] * influencer_tweet2)*profitmargin - tweet_cost_analytics
Total_perfect = df1["Expected_Return_Perfect"].sum()
print("Total Expected Return with perfect analytics is $", round(Total_perfect,2))
print("The increase in net profit from using a perfect analytic model is $",round(Total_perfect - Total_noanalytics,2))
# Out:
# Total Expected Return with perfect analytics is $ 981698.82
# The increase in net profit from using a perfect analytic model is $ 328149.61

# %%
###With Analytics
df1['Expected_Return_Analytics'] = df1['Expected_Return_Perfect']
df1.loc[df1.index.isin(wrong_observations), 'Expected_Return_Analytics'] = -tweet_cost_analytics
df1.head()
# Out:
#     Choice  A_follower_count  A_following_count  A_listed_count  \
# 33       1            130850               3394             449
# 40       0            627949             150866            6820
# 51       1            232753                320            7919
# 64       1           1352348                331           15647
# 67       0             49326              42259            1446
#
#     A_mentions_received  A_retweets_received  A_mentions_sent  \
# 33            92.869651            16.538484         2.548048
# 40           246.403846            74.705430        21.260939
# 51           175.264776           100.480820         3.108490
# 64         19129.848662         14552.733991         2.065418
# 67             0.452340             0.275538         0.100503
#
#     A_retweets_sent    A_posts  A_network_feature_1  ...  B_retweets_received  \
# 33         0.100503   3.036688                  355  ...             0.100503
# 40         1.320681  15.278066                  683  ...            27.797596
# 51         1.614717   4.401919                  679  ...           763.659739
# 64         0.580955  16.281502                52580  ...            22.321945
# 67         0.100503   0.100503                    2  ...          2944.524245
#
#     B_mentions_sent  B_retweets_sent    B_posts  B_network_feature_1  \
# 33         0.100503         0.100503   0.595962                    2
# 40         0.796262         0.332423   0.332423                  430
# 51        30.829977         8.568367  93.311571                 4067
# 64         6.946233         0.341936   6.503977                  202
# 67        12.955723         2.791861  66.206208                21678
#
#     B_network_feature_2  B_network_feature_3  Expected_Return_No_Analytics  \
# 33           836.000000         11447.500000                         251.7
# 40           241.680460          8490.301149                        106.18
# 51            12.310269          1636.379704                       455.506
# 64           152.495098          3286.617647                      2694.696
# 67             6.859364          1113.202016                      4537.742
#
#     Expected_Return_Perfect  Expected_Return_Analytics
# 33                   382.55                     382.55
# 40                   164.27                        -10
# 51                  688.259                        -10
# 64                 4047.044                   4047.044
# 67                 6811.613                   6811.613
#
# [5 rows x 26 columns]

# %%
Total_model = df1["Expected_Return_Analytics"].sum()
print("Total Expected Return with analytics is $", round(Total_model,2))
print("The increase in net profit from using an analytic model is $",round(Total_model - Total_noanalytics,2))
# Out:
# Total Expected Return with analytics is $ 932271.51
# The increase in net profit from using an analytic model is $ 278722.29

# %% [markdown]
# Part 2: Finding Influencers from Twitter

# %% [markdown]
# ### Tweet Scraping

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import matplotlib.pyplot as plt
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import requests
from datetime import datetime, timedelta
import requests
import pandas as pd
import re

from datetime import datetime, timedelta
import requests
import pandas as pd
import yfinance as yf
from datetime import datetime
from datetime import datetime, timedelta
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAANeNZAEAAAAAWqEd3GXb3R8V%2FdhbCITAL%2BHA9RM%3D32FXQSrOUqzLm0LSmsKnq75B9CwIZLtsH3OAoG8HsgyC08Jrra'

# %%
# setup the API request
ref= 'https://api.twitter.com/2/tweets/search/recent'

headers= {'authorization': f'Bearer {BEARER_TOKEN}'}
params= {
    'query': '(Champions league OR UCL) (lang:en)',
    'max_results': '100',
    'tweet.fields': 'created_at,lang,author_id',
    #'expansions': 'entities.mentions.username',
    #'user.fields': 'username'
}

# %%
#Function to get data from the requests
def get_data(tweet):
    data = {'id':tweet['id'],
            'author_id':tweet['author_id'],
            #'username':tweet['entities']['mentions'][0]['username'],
            #'username_id': tweet['entities']['mentions'][0]['id'],
        'created_at':tweet['created_at'],
        'text':tweet['text']}
    return data

#tweet['entities']['mentions'][0]['username']

# %%
dtformat = '%Y-%m-%dT%H:%M:%SZ'  # Setting the date format required by twitter API

# %%
# function that subtracts 60 min from the current datetime
def time_slots(end_date, mins):
    date = datetime.strptime(end_date, dtformat)
    back_in_time = date - timedelta(minutes=mins)
    return back_in_time.strftime(dtformat)

#date = '2022-03-16T23:55:55Z'

# %%
#Defining current hour
date = '16/03/22 23:59:00'
date = datetime.strptime(date, '%d/%m/%y %H:%M:%S') # get current datetime

last_week = date - timedelta(days=2)  # datetime 7 days ago
date = date.strftime(dtformat)  # convert current datetime to format for twitter API

# %%
df = pd.DataFrame()  # initialize dataframe

# %%
while True:
    
    if (datetime.strptime(date, dtformat) < last_week):
        # break the loop when we reach one week ago
        break
    
    go_back = time_slots(date, 55)  # get 60 minutes before 'now'
    
    # setting starting and end time for the API
    params['start_time'] = go_back
    params['end_time'] = date
    
    #Sending request
    response = requests.get(ref,
                            params=params,
                            headers=headers)
    
    date = go_back  # moving back the window by 60 min
    
    # Adding the tweets data to the dataframe
    for tweet in response.json()['data']:
        row = get_data(tweet)  # we defined this function earlier
        df = df.append(row, ignore_index=True)

# %%
#converting 'created_at' to date time
df.created_at = pd.to_datetime(df['created_at'])

df.to_csv(data_dir+'tweets_ucl_noUsername.csv')

# %%
from twitterUsernameviaUserID import getHandles as gH
temp = gH.getHandles(df.author_id.tolist(), 10)

id_to_username_df = pd.DataFrame(list(temp.items()), columns=['author_id', 'username'])
id_to_username_df.to_csv('C:/Users/Mehdi/Desktop/id_to_username_df.csv')

# %%
df_final = pd.merge(df,id_to_username_df, how='left', on='author_id')

#Check
print(df_final.isnull().sum())

df_final.to_csv(data_dir+'final_tweets_df.csv')

# %% [markdown]
# ### Creating Tweet Table

# %%
df = pd.read_csv(data_dir+'final_tweets_df.csv')
df
# Out:
#       Unnamed: 0                   id            author_id  \
# 0              0  1504245878558707714  1366820532923101184
# 1              1  1504245878135025665             38776130
# 2              2  1504245877220814849  1468527026105876482
# 3              3  1504245875358543872  1103955773015642112
# 4              4  1504245872414056458   734688391942524928
# ...          ...                  ...                  ...
# 5252        5252  1503525363711885312  1241588020194750469
# 5253        5253  1503525359823699968             49922295
# 5254        5254  1503525355407224833            473985504
# 5255        5255  1503525327515136003            550464808
# 5256        5256  1503525319126441986           2716611263
#
#                      created_at  \
# 0     2022-03-16 23:58:59+00:00
# 1     2022-03-16 23:58:59+00:00
# 2     2022-03-16 23:58:59+00:00
# 3     2022-03-16 23:58:58+00:00
# 4     2022-03-16 23:58:58+00:00
# ...                         ...
# 5252  2022-03-15 00:15:55+00:00
# 5253  2022-03-15 00:15:54+00:00
# 5254  2022-03-15 00:15:53+00:00
# 5255  2022-03-15 00:15:46+00:00
# 5256  2022-03-15 00:15:44+00:00
#
#                                                    text  author_username  \
# 0     RT @Blue_Footy: Chelsea went out in the round ...         QuesiTee
# 1     RT @JamesOlley: Tuchel asked about Uefa bannin...  tommyboyjazzman
# 2     RT @premierleague: Through to the next round o...       ellah_maih
# 3     RT @CesarAzpi: Together into the next round!! ...  OkerekeChidieb2
# 4     RT @UCLSoM: Do NFTs contradict the net-zero ta...  stratisplatform
# ...                                                 ...              ...
# 5252  RT @ChampionsLeague: 𝐇𝐢𝐬𝐭𝐨𝐫𝐢𝐜.\r\n\r\n#UCL htt...     aguslazzaro_
# 5253  RT @LAConqsGBBall: Congrats to the Lady Conqs ...       ErikSarni1
# 5254  RT @ArsenalWFC: Coming soon: Champions League ...          Lammoye
# 5255  RT @ManUtd: Old Trafford awaits... 🏟✨\r\n\r\n#...      DaniNunez__
# 5256  @pacoslik @HardTimeSuspect @gyaigyimii A lot o...        phlexkhid
#
#              username
# 0            QuesiTee
# 1     tommyboyjazzman
# 2          ellah_maih
# 3     OkerekeChidieb2
# 4     stratisplatform
# ...               ...
# 5252     aguslazzaro_
# 5253       ErikSarni1
# 5254          Lammoye
# 5255      DaniNunez__
# 5256        phlexkhid
#
# [5257 rows x 7 columns]

# %%
df = df[['username', 'text']]
df
# Out:
#              username                                               text
# 0            QuesiTee  RT @Blue_Footy: Chelsea went out in the round ...
# 1     tommyboyjazzman  RT @JamesOlley: Tuchel asked about Uefa bannin...
# 2          ellah_maih  RT @premierleague: Through to the next round o...
# 3     OkerekeChidieb2  RT @CesarAzpi: Together into the next round!! ...
# 4     stratisplatform  RT @UCLSoM: Do NFTs contradict the net-zero ta...
# ...               ...                                                ...
# 5252     aguslazzaro_  RT @ChampionsLeague: 𝐇𝐢𝐬𝐭𝐨𝐫𝐢𝐜.\r\n\r\n#UCL htt...
# 5253       ErikSarni1  RT @LAConqsGBBall: Congrats to the Lady Conqs ...
# 5254          Lammoye  RT @ArsenalWFC: Coming soon: Champions League ...
# 5255      DaniNunez__  RT @ManUtd: Old Trafford awaits... 🏟✨\r\n\r\n#...
# 5256        phlexkhid  @pacoslik @HardTimeSuspect @gyaigyimii A lot o...
#
# [5257 rows x 2 columns]

# %%
df = df.rename(columns = {'username': 'handle'})
df
# Out:
#                handle                                               text
# 0            QuesiTee  RT @Blue_Footy: Chelsea went out in the round ...
# 1     tommyboyjazzman  RT @JamesOlley: Tuchel asked about Uefa bannin...
# 2          ellah_maih  RT @premierleague: Through to the next round o...
# 3     OkerekeChidieb2  RT @CesarAzpi: Together into the next round!! ...
# 4     stratisplatform  RT @UCLSoM: Do NFTs contradict the net-zero ta...
# ...               ...                                                ...
# 5252     aguslazzaro_  RT @ChampionsLeague: 𝐇𝐢𝐬𝐭𝐨𝐫𝐢𝐜.\r\n\r\n#UCL htt...
# 5253       ErikSarni1  RT @LAConqsGBBall: Congrats to the Lady Conqs ...
# 5254          Lammoye  RT @ArsenalWFC: Coming soon: Champions League ...
# 5255      DaniNunez__  RT @ManUtd: Old Trafford awaits... 🏟✨\r\n\r\n#...
# 5256        phlexkhid  @pacoslik @HardTimeSuspect @gyaigyimii A lot o...
#
# [5257 rows x 2 columns]

# %% [markdown]
# ### Second dataframe: retweets

# %%
col_2_keys = []
col_2_values = []
for i in range(len(df.text)):
    if 'RT' in df.text[i]:
        col_2_keys.append(df.text[i].split(' ')[1])
        col_2_values.append(df.text[i].split(' ')[1])
        col_2_keys.append(df.handle[i])
        col_2_values.append(df.text[i].split(' ')[1])
#col_2_keys
#col_2_values

col_2_dict = dict(col1 = col_2_keys, col2 = col_2_values)

# %%
rt = pd.DataFrame(col_2_dict)

# %%
col3 = []
for i in range(len(rt)):
    if rt.col1[i] == rt.col2[i]:
        col3.append('Tweet')
    elif rt.col1[i] != rt.col2[i]:
        col3.append('Retweet')
rt['col3'] = col3
rt
# Out:
#                  col1             col2     col3
# 0        @Blue_Footy:     @Blue_Footy:    Tweet
# 1            QuesiTee     @Blue_Footy:  Retweet
# 2        @JamesOlley:     @JamesOlley:    Tweet
# 3     tommyboyjazzman     @JamesOlley:  Retweet
# 4     @premierleague:  @premierleague:    Tweet
# ...               ...              ...      ...
# 8353       ErikSarni1  @LAConqsGBBall:  Retweet
# 8354     @ArsenalWFC:     @ArsenalWFC:    Tweet
# 8355          Lammoye     @ArsenalWFC:  Retweet
# 8356         @ManUtd:         @ManUtd:    Tweet
# 8357      DaniNunez__         @ManUtd:  Retweet
#
# [8358 rows x 3 columns]

# %%
for i in range(len(rt.col1)):
    if '@' not in rt.col1[i]:
        rt.col1[i] = '@' + rt.col1[i]
rt.col1
# Out:
# 0           @Blue_Footy:
# 1              @QuesiTee
# 2           @JamesOlley:
# 3       @tommyboyjazzman
# 4        @premierleague:
#               ...
# 8353         @ErikSarni1
# 8354        @ArsenalWFC:
# 8355            @Lammoye
# 8356            @ManUtd:
# 8357        @DaniNunez__
# Name: col1, Length: 8358, dtype: object

# %%
for i in range(len(rt.col1)):
    if ':' in rt.col1[i]:
        rt.col1[i] = rt.col1[i].replace(':', '')
rt.col1
# Out:
# 0            @Blue_Footy
# 1              @QuesiTee
# 2            @JamesOlley
# 3       @tommyboyjazzman
# 4         @premierleague
#               ...
# 8353         @ErikSarni1
# 8354         @ArsenalWFC
# 8355            @Lammoye
# 8356             @ManUtd
# 8357        @DaniNunez__
# Name: col1, Length: 8358, dtype: object

# %%
for i in range(len(rt.col2)):
    if ':' in rt.col2[i]:
        rt.col2[i] = rt.col2[i].replace(':', '')
rt.col2
# Out:
# 0          @Blue_Footy
# 1          @Blue_Footy
# 2          @JamesOlley
# 3          @JamesOlley
# 4       @premierleague
#              ...
# 8353    @LAConqsGBBall
# 8354       @ArsenalWFC
# 8355       @ArsenalWFC
# 8356           @ManUtd
# 8357           @ManUtd
# Name: col2, Length: 8358, dtype: object

# %%
rt
# Out:
#                   col1            col2     col3
# 0          @Blue_Footy     @Blue_Footy    Tweet
# 1            @QuesiTee     @Blue_Footy  Retweet
# 2          @JamesOlley     @JamesOlley    Tweet
# 3     @tommyboyjazzman     @JamesOlley  Retweet
# 4       @premierleague  @premierleague    Tweet
# ...                ...             ...      ...
# 8353       @ErikSarni1  @LAConqsGBBall  Retweet
# 8354       @ArsenalWFC     @ArsenalWFC    Tweet
# 8355          @Lammoye     @ArsenalWFC  Retweet
# 8356           @ManUtd         @ManUtd    Tweet
# 8357      @DaniNunez__         @ManUtd  Retweet
#
# [8358 rows x 3 columns]

# %%
rt.to_csv(data_dir+'Tweet_table.csv', index = False)

# %% [markdown]
# ### Generating the Network Diagram

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Import Network Diagram

# %%
network_df = pd.read_csv(data_dir+'Tweet_table.csv')
network_df.columns = ['user1', 'user2', 'type']

# %%
network_df
# Out:
#                  user1           user2     type
# 0          @Blue_Footy     @Blue_Footy    Tweet
# 1            @QuesiTee     @Blue_Footy  Retweet
# 2          @JamesOlley     @JamesOlley    Tweet
# 3     @tommyboyjazzman     @JamesOlley  Retweet
# 4       @premierleague  @premierleague    Tweet
# ...                ...             ...      ...
# 8353       @ErikSarni1  @LAConqsGBBall  Retweet
# 8354       @ArsenalWFC     @ArsenalWFC    Tweet
# 8355          @Lammoye     @ArsenalWFC  Retweet
# 8356           @ManUtd         @ManUtd    Tweet
# 8357      @DaniNunez__         @ManUtd  Retweet
#
# [8358 rows x 3 columns]

# %% [markdown]
# ### Graph Functions

# %%
# Generate degree distribution plots function

def degree_dist(G):
    degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
    dmax = max(degree_sequence)

    fig = plt.figure("Degree of graph", figsize=(8, 8))
    # Create a gridspec for adding subplots of different sizes
    axgrid = fig.add_gridspec(5, 4)

    ax1 = fig.add_subplot(axgrid[3:, :2])
    ax1.plot(degree_sequence, "b-", marker="o")
    ax1.set_title("Degree Rank Plot")
    ax1.set_ylabel("Degree")
    ax1.set_xlabel("Rank")

    ax2 = fig.add_subplot(axgrid[3:, 2:])
    ax2.bar(*np.unique(degree_sequence, return_counts=True))
    ax2.set_title("Degree histogram")
    ax2.set_xlabel("Degree")
    ax2.set_ylabel("# of Nodes")

    fig.tight_layout()
    plt.show()

# %% [markdown]
# ### Generate Graph

# %%
def gen_graph(network_df):
    rt_in = network_df.type=='Retweet'
    rts = network_df[rt_in]
    tweets = network_df.drop(index= rts.index)
    graph = nx.DiGraph()
    graph.add_edges_from(zip(rts.user1, rts.user2), ttype = 'RT')
    graph.add_edges_from(zip(tweets.user1, tweets.user2), ttype = 'tweet')
    return graph

# %%
graph = gen_graph(network_df)

# %% [markdown]
# ### Draw Simple Graph

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)
nx.draw_networkx(graph, font_size = 10, with_labels=False)
plt.show()

# %% [markdown]
# ### Network Features

# %%
degree = pd.DataFrame(pd.Series(dict(graph.degree)), columns=['degree'])

# %%
centrality = pd.Series(nx.algorithms.centrality.betweenness.betweenness_centrality(graph)).sort_values()

# %%
closeness = pd.Series(nx.algorithms.centrality.closeness.closeness_centrality(graph)).sort_values(ascending=False)

# %%
retweets_res = network_df[network_df.type == "Retweet"].groupby('user2').aggregate({'type':'count'})
retweets_res.columns = ['retweet']

# %% [markdown]
# ### User Features

# %%
user_df = pd.read_csv(directory+'users_info_df.csv')
user_df.drop_duplicates(inplace=True, subset='screen_name')
user_df.set_index('@'+user_df.screen_name , drop = True, inplace = True) 
user_df = user_df.iloc[:, 3:]
user_df = user_df.join([degree, retweets_res])
user_df.fillna(0, inplace = True)

# %%
user_df
# Out:
#                   followers_count  friends_count  listed_count  \
# screen_name
# @QuesiTee                   278.0         1117.0           1.0
# @tommyboyjazzman            217.0         1263.0           5.0
# @ellah_maih                 212.0          236.0           0.0
# @OkerekeChidieb2            500.0          480.0           1.0
# @stratisplatform         161079.0          193.0        1806.0
# ...                           ...            ...           ...
# @ThePaulMachin            59733.0         1521.0         259.0
# @ValencyWiry                 68.0           95.0           0.0
# @AyewAndre               598521.0           74.0         656.0
# @RMadridEngineer          15676.0         2161.0         105.0
# @LAConqsGBBall              216.0          225.0           0.0
#
#                   statuses_count  degree  retweet
# screen_name
# @QuesiTee                26017.0     1.0      0.0
# @tommyboyjazzman          1102.0     2.0      0.0
# @ellah_maih               8423.0     1.0      0.0
# @OkerekeChidieb2          5988.0     1.0      0.0
# @stratisplatform          2458.0     1.0      0.0
# ...                          ...     ...      ...
# @ThePaulMachin           19178.0     3.0      1.0
# @ValencyWiry               143.0     3.0      1.0
# @AyewAndre                1464.0     3.0      1.0
# @RMadridEngineer         16789.0     3.0      1.0
# @LAConqsGBBall             573.0     3.0      1.0
#
# [5304 rows x 6 columns]

# %% [markdown]
# ### Influencer Scores

# %%
scaler = StandardScaler()
user_df = pd.DataFrame(scaler.fit_transform(user_df), columns=user_df.columns, index = user_df.index)

# %%
weights = pd.read_csv(directory+'Weights_v2.csv', index_col=0).T

# %%
weights
# Out:
# Feature  Listed  Followers  Retweets  Feature 1  Posts
# Weight    0.299      0.244     0.202      0.143  0.112

# %%
user_df['score'] = weights.Listed[0]*user_df.listed_count\
                    +weights.Followers[0]*user_df.followers_count\
                    +weights.Retweets[0]*user_df.retweet\
                    +weights['Feature 1'][0]*user_df.degree\
                    +weights.Posts[0]*user_df.statuses_count

# %% [markdown]
# ### Top 100 Influencers

# %%
top100 = list(user_df.nlargest(100, columns=['score']).index)
top100scores =  list(user_df.score.nlargest(100))

# %%
top100
# Out:
# ['@ManUtd',
#  '@ChampionsLeague',
#  '@ChelseaFC',
#  '@FCBarcelona',
#  '@BBCNews',
#  '@premierleague',
#  '@ESPNFC',
#  '@LFC',
#  '@TrollFootball',
#  '@BBCSport',
#  '@D_DeGea',
#  '@goal',
#  '@brfootball',
#  '@SkySportsNews',
#  '@realmadriden',
#  '@SkySportsPL',
#  '@FabrizioRomano',
#  '@SkySports',
#  '@Squawka',
#  '@Football__Tweet',
#  '@paulpogba',
#  '@united',
#  '@OptaJoe',
#  '@alimo_philip',
#  '@SportsbookBTC',
#  '@btsportfootball',
#  '@UtdDistrict',
#  '@SuperSportTV',
#  '@Tunnykvng',
#  '@stephenoflyf',
#  '@UnitedStandMUFC',
#  '@ReciteSocial',
#  '@FOXSoccer',
#  '@EURO2024',
#  '@talkSPORT',
#  '@Yemihazan',
#  '@kofoworola__a',
#  '@sudeepkhatri',
#  '@ESPNUK',
#  '@WhoScored',
#  '@scarfizal',
#  '@FootyAccums',
#  '@DeadlineDayLive',
#  '@Tochi83923928',
#  '@AFCAjax',
#  '@utdreport',
#  '@UTDTrey',
#  '@Omojuwa',
#  '@433',
#  '@leah_rm13',
#  '@CesarAzpi',
#  '@ManUtdMEN',
#  '@DailyPostNGR',
#  '@MailSport',
#  '@EdmundOris',
#  '@NizaarKinsella',
#  '@Bapt_4_4',
#  '@Glasgow_Watch',
#  '@GoalNews',
#  '@RobDawsonESPN',
#  '@ewnupdates',
#  '@sportbible',
#  '@CFCDaily',
#  '@sportingindex',
#  '@UtdPlug',
#  '@footballitalia',
#  '@WilliamHill',
#  '@TheMasterBucks',
#  '@TeleFootball',
#  '@FootballFunnnys',
#  '@vdsar1970',
#  '@OlisaOsega',
#  '@KhalidAlKhudair',
#  '@MrZeeshanMasih',
#  '@beINSPORTS_EN',
#  '@fishtrenado',
#  '@AnfieldEdition',
#  '@MystiqueJerseys',
#  '@SLBenfica',
#  '@VillarrealCF',
#  '@PhilKitro',
#  '@JoseHndz93',
#  '@CelticFC',
#  '@TheImmortalKop',
#  '@FTalentScout',
#  '@starboy__16',
#  '@OllieHolt22',
#  '@MadridXtra',
#  '@BarcaWorldwide',
#  '@PhoqueZeOuate',
#  '@Joshua_Ubeku',
#  '@angelomangiante',
#  '@Kayjnr10',
#  '@theMadridZone',
#  '@Soccer_Laduma',
#  '@Footballogue',
#  '@BenDinnery',
#  '@CryptoWhale',
#  '@TimelineCR7',
#  '@NenyeChelsea']

# %%
top_100_ext = network_df[(network_df.user1.isin(top100)|network_df.user2.isin(top100))]
top_100_ext_rt = top_100_ext[top_100_ext.type == 'Retweet']
top_100_nodes = network_df[(network_df.user1.isin(top100)&network_df.user2.isin(top100))]
top_100_nodes_rt = top_100_nodes[top_100_nodes.type == 'Retweet']

# %%
top_100_ext_rt
# Out:
#                  user1             user2     type
# 5          @ellah_maih    @premierleague  Retweet
# 7     @OkerekeChidieb2        @CesarAzpi  Retweet
# 11     @caesar_abraham             @goal  Retweet
# 13       @NbaSabonkudi    @TrollFootball  Retweet
# 15         @soaresmr10   @BarcaWorldwide  Retweet
# ...                ...               ...      ...
# 8345      @KvngAyo2001        @ChelseaFC  Retweet
# 8347         @rusev158      @UtdDistrict  Retweet
# 8349        @itz_ladon           @ESPNFC  Retweet
# 8351     @aguslazzaro_  @ChampionsLeague  Retweet
# 8357      @DaniNunez__           @ManUtd  Retweet
#
# [2802 rows x 3 columns]

# %% [markdown]
# ### Retweets recieved by top influencers

# %%
graph = gen_graph(top_100_ext_rt)

# %%
degree_dist(graph)

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)
nx.draw_networkx(graph, font_size = 10, with_labels=False)
plt.show()

# %% [markdown]
# ### Posts made by top influencers

# %%
graph = gen_graph(top_100_nodes)

# %%
degree_dist(graph)

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)
pos = nx.spring_layout(graph)
nx.draw_networkx(graph, pos, font_size = 10)
plt.show()

# %% [markdown]
# ### Retweets between top Influencers

# %%
graph = gen_graph(top_100_nodes_rt)

# %%
degree_dist(graph)

# %%
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(10)
pos = nx.spring_layout(graph)
nx.draw_networkx(graph, pos, font_size = 10)
plt.show()
